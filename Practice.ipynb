# %%
my_string = "Hello world"
i = my_string.find('or')  # 'or' exist in the the string
print(i)
# Out:
# 7

# %%
my_string = "Hello world"
i = my_string.find('p')    # 'p' does not exist in the string
print(i)

g = my_string.replace('H', 'N')
print(g)
# Out:
# -1
# Nello world

# %%
my_dictionary = {'banana': 1, 12: 'laptop', (0,0):'center'}
my_dictionary['banana']
# Out:
# 1

# %%
my_dictionary.keys()
# Out:
# dict_keys(['banana', 12, (0, 0)])

# %%
my_dictionary.values()
# Out:
# dict_values([1, 'laptop', 'center'])

# %%
my_collection = [1, 1, 3.12, False, "Hi"]
len(my_collection)
my_collection.extend(["motor", "lorry", "camp"])
print(my_collection)
my_collection.append("single item")
print(my_collection)

del(my_collection[6])
print(my_collection)

my_clone= my_collection[:]
print(my_collection)

list_items = my_clone + my_collection
print(list_items)

numbers = [1, 2, 3, 4, 5, 6, 7]
sum(numbers)

for i in my_clone:
  if i == 'motor':
    print("This is the work")
  else:
    print("Not again!")
# Out:
# [1, 1, 3.12, False, 'Hi', 'motor', 'lorry', 'camp']
# [1, 1, 3.12, False, 'Hi', 'motor', 'lorry', 'camp', 'single item']
# [1, 1, 3.12, False, 'Hi', 'motor', 'camp', 'single item']
# [1, 1, 3.12, False, 'Hi', 'motor', 'camp', 'single item']
# [1, 1, 3.12, False, 'Hi', 'motor', 'camp', 'single item', 1, 1, 3.12, False, 'Hi', 'motor', 'camp', 'single item']
# Not again!
# Not again!
# Not again!
# Not again!
# Not again!
# This is the work
# Not again!
# Not again!

# %%
numbers = [1, 2, 3, 4, 5, 6, 7]
print(48 in numbers)
print(5 in numbers)
print(23 not in numbers)
print(3 not in numbers)
# Out:
# False
# True
# True
# False

# %%
my_set = set([1, 738, 22])

# %%
for a in range(2, 23, 8):
  print(a*3)
# Out:
# 6
# 30
# 54

# %% [markdown]
# while loop
# A while loop in Python repeatedly executes a block of code as long as a given condition is True
#
# syntax:
#    while **condition:**
#                                                                *# code to execute*

# %%
count = 0
while count < 5:
  print("Count is:", count)
  count += 1    # Increment count to avoid infinite loop
# Out:
# Count is: 0
# Count is: 1
# Count is: 2
# Count is: 3
# Count is: 4

# %%
i = 0
while i < 10:
  print(i, "\n")
  if i == 5:
    break;
  #print(i)
  i += 1
# Out:
# 0
#
# 1
#
# 2
#
# 3
#
# 4
#
# 5

# %%
# Error handling in Python

try:
  # Code that may arise an exception
  x = 10/0   # Division by zero error
except ZeroDivisionError  as e:
  print(f"Error: {e}")  # Handle the error
else:
  print("No errors ocurred!")  # Execute if no exception ocurrs
finally:
  print("Execute no matter what!")
# Out:
# Error: division by zero
# Execute no matter what!

# %%
#print(5/0)

try:
  print(5/0)
except ZeroDivisionError:
  print("You can't divide by zero!")
# Out:
# You can't divide by zero!

# %%
print("Give me two numbers and i will divide them.")
print("Enter 'q' to quit.")

while True:
  first_number = input("\nFirst number: ")
  if first_number == 'q':
    break;
  second_number = input("\nSecond number: ")
  if second_number == 'q':
    break;

  try:
    answer = int(first_number) / int(second_number)
  except ZeroDivisionError:
    print("You cannot divide by 0")
  else:
    print("The answer is:", answer)
# Out:
# Give me two numbers and i will divide them.
# Enter 'q' to quit.
#
# First number: 5
#
# Second number: 0
# You cannot divide by 0
#
# First number: 432
#
# Second number: 44
# The answer is: 9.818181818181818
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-13b313854260> in <cell line: 0>()
#       3
#       4 while True:
# ----> 5   first_number = input("\nFirst number: ")
#       6   if first_number == 'q':
#       7     break;
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# ...

# %%
class Car:
  def __init__(self, brand, model, year):
    self.brand = brand      #Attribute
    self.model = model
    self.year = year

  def display_info(self):     # Method
    return  f"{self.brand}  {self.model}  {self.year}"

# Creating an object(instance of the class)
my_car = Car("Toyota", "corolla", 2022)

# %%
# Accessing attribute
print(my_car.brand)
# Out:
# Toyota

# %%
# Calling methods
print(my_car.display_info())
# Out:
# Toyota  corolla  2022
